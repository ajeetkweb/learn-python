# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./data/Income.csv")
df.head()
# Out:
#     Name  Age  Income($)
# 0   Ajit   29      50000
# 1   Amit   27      40000
# 2    Sam   48      60000
# 3  Mohan   47      65000
# 4    Ram   50      80000

# %%
plt.scatter(df['Age'], df['Income($)'])
plt.xlabel('Age')
plt.ylabel('Income($)')
plt.show()

# %%
kmeans = KMeans(n_clusters  = 3)
y_predicted = kmeans.fit_predict(df[['Age', 'Income($)']])
y_predicted
# Out:
# array([2, 2, 0, 0, 0, 2, 2, 0, 0, 1, 1, 1], dtype=int32)

# %%
df['cluster'] = y_predicted
df
# Out:
#        Name  Age  Income($)  cluster
# 0      Ajit   29      50000        2
# 1      Amit   27      40000        2
# 2       Sam   48      60000        0
# 3     Mohan   47      65000        0
# 4       Ram   50      80000        0
# 5      Raju   25      30000        2
# 6     Mohit   24      25000        2
# 7   Krishna   52      90000        0
# 8      Alok   60     100000        0
# 9      Arya   61     150000        1
# 10     Anju   62     120000        1
# 11    Sanju   63     130000        1

# %%
kmeans.cluster_centers_
# Out:
# array([[5.14000000e+01, 7.90000000e+04],
#        [6.20000000e+01, 1.33333333e+05],
#        [2.62500000e+01, 3.62500000e+04]])

# %%
kmeans.inertia_
# Out:
# 1955416790.6166668

# %%
df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]
df3 = df[df.cluster == 2]

# %%
df1
# Out:
#       Name  Age  Income($)  cluster
# 2      Sam   48      60000        0
# 3    Mohan   47      65000        0
# 4      Ram   50      80000        0
# 7  Krishna   52      90000        0
# 8     Alok   60     100000        0

# %%
df2
# Out:
#      Name  Age  Income($)  cluster
# 9    Arya   61     150000        1
# 10   Anju   62     120000        1
# 11  Sanju   63     130000        1

# %%
df3
# Out:
#     Name  Age  Income($)  cluster
# 0   Ajit   29      50000        2
# 1   Amit   27      40000        2
# 5   Raju   25      30000        2
# 6  Mohit   24      25000        2

# %%
plt.scatter(df1['Age'], df1['Income($)'], color = 'green')
plt.scatter(df2['Age'], df2['Income($)'], color = 'red')
plt.scatter(df3['Age'], df3['Income($)'], color = 'blue')
plt.xlabel('Age')
plt.ylabel('Income($)')
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6812\450692868.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Scaling data

# %%
scaler = MinMaxScaler()
scaler.fit(df[['Income($)']])
df['Income($)'] = scaler.transform(df[['Income($)']])
df
# Out:
#        Name  Age  Income($)  cluster
# 0      Ajit   29       0.20        2
# 1      Amit   27       0.12        2
# 2       Sam   48       0.28        0
# 3     Mohan   47       0.32        0
# 4       Ram   50       0.44        0
# 5      Raju   25       0.04        2
# 6     Mohit   24       0.00        2
# 7   Krishna   52       0.52        0
# 8      Alok   60       0.60        0
# 9      Arya   61       1.00        1
# 10     Anju   62       0.76        1
# 11    Sanju   63       0.84        1

# %%
scaler.fit(df[['Age']])
df['Age'] = scaler.transform(df[['Age']])

# %%
df
# Out:
#        Name       Age  Income($)  cluster
# 0      Ajit  0.128205       0.20        0
# 1      Amit  0.076923       0.12        0
# 2       Sam  0.615385       0.28        1
# 3     Mohan  0.589744       0.32        1
# 4       Ram  0.666667       0.44        1
# 5      Raju  0.025641       0.04        0
# 6     Mohit  0.000000       0.00        0
# 7   Krishna  0.717949       0.52        1
# 8      Alok  0.923077       0.60        2
# 9      Arya  0.948718       1.00        2
# 10     Anju  0.974359       0.76        2
# 11    Sanju  1.000000       0.84        2

# %%
plt.scatter(df1['Age'], df1['Income($)'], color = 'green')
plt.scatter(df2['Age'], df2['Income($)'], color = 'red')
plt.scatter(df3['Age'], df3['Income($)'], color = 'blue')
plt.xlabel('Age')
plt.ylabel('Income($)')
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6812\450692868.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
km = KMeans(n_clusters = 3)
y_predicted = km.fit_predict(df[['Age', 'Income($)']])

y_predicted
# Out:
# array([1, 1, 2, 2, 2, 1, 1, 2, 0, 0, 0, 0], dtype=int32)

# %%
df['cluster'] = y_predicted
df
# Out:
#        Name       Age  Income($)  cluster
# 0      Ajit  0.128205       0.20        1
# 1      Amit  0.076923       0.12        1
# 2       Sam  0.615385       0.28        2
# 3     Mohan  0.589744       0.32        2
# 4       Ram  0.666667       0.44        2
# 5      Raju  0.025641       0.04        1
# 6     Mohit  0.000000       0.00        1
# 7   Krishna  0.717949       0.52        2
# 8      Alok  0.923077       0.60        0
# 9      Arya  0.948718       1.00        0
# 10     Anju  0.974359       0.76        0
# 11    Sanju  1.000000       0.84        0

# %%
km.cluster_centers_
# Out:
# array([[0.96153846, 0.8       ],
#        [0.05769231, 0.09      ],
#        [0.6474359 , 0.39      ]])

# %%
km.inertia_
# Out:
# 0.16588244575936884

# %%
df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]
df3 = df[df.cluster == 2]

# %%
plt.scatter(df1['Age'], df1['Income($)'], color = 'green')
plt.scatter(df2['Age'], df2['Income($)'], color = 'red')
plt.scatter(df3['Age'], df3['Income($)'], color = 'blue')
plt.xlabel('Age')
plt.ylabel('Income($)')
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6812\450692868.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df2
# Out:
#      Name       Age  Income($)  cluster
# 8    Alok  0.923077       0.60        1
# 9    Arya  0.948718       1.00        1
# 10   Anju  0.974359       0.76        1
# 11  Sanju  1.000000       0.84        1

# %% [markdown]
# ## Elbow Method
#
# ### SSE - sum of squired Errors

# %%
sse = []

k_rang = range(1,10)

for k in k_rang:
    km = KMeans(n_clusters = k)
    km.fit(df[['Age','Income($)']])
    sse.append(km.inertia_)

sse
# Out:
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ak8184\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [2.8666768354152965,
#  0.6994032873109794,
#  0.16588244575936884,
#  0.1056527722989261,
#  0.06717107166337934,
#  0.042468902038132784,
#  0.014816042077580544,
#  0.010301117685733078,
#  0.005786193293885612]

# %%
plt.xlabel('K')
plt.ylabel('Sum of squired errors (SSE)')
plt.plot(k_rang, sse)
