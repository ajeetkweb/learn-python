# %% [markdown]
# ## sns.histplot()

# %% [markdown]
# ### A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within discrete bins.

# %% [markdown]
# ### seaborn.histplot(data=None, *, x=None, y=None, hue=None, bins='auto')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris  = pd.read_csv("../Iris.csv")
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.histplot(data = iris, bins = 50)
plt.show()

# %%
sns.histplot(data = iris, x = 'SepalLengthCm', bins = 40)
plt.show()

# %%
sns.histplot(data = iris, x = 'PetalLengthCm', binwidth = 0.3, bins=40)
plt.show()

# %%
sns.histplot(data = iris, x = 'PetalLengthCm',  kde=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(data=iris, x="SepalLengthCm", hue="Species", bins = 20)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
tips = pd.read_csv("tips.csv")
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.histplot(data = tips, x = 'day')
plt.show()

# %%
sns.histplot(data = tips, x = 'day', hue='sex',  multiple="dodge", shrink=.8)
# Out:
# <Axes: xlabel='day', ylabel='Count'>
