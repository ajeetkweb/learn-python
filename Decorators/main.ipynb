# %%
def my_decorator(func):
    def wrapper():
        print('Before function call')
        func()
        print("After function call")

    return wrapper


@my_decorator
def say_hello():
    print("Hello, World!")


say_hello()
# Out:
# Before function call
# Hello, World!
# After function call

# %% [markdown]
# ### Logging

# %%
def log_calls(func):
    def wrapper(*args, **kwargs):
        print(f"calling function {func.__name__} with args: {args}")
        result = func(*args, **kwargs)
        return result
    return wrapper

@log_calls
def add_number(a, b):
    print('Adding numbers')
    return a + b

print(add_number(5, 10))
# Out:
# calling function add_number with args: (5, 10)
# Adding numbers
# 15

# %% [markdown]
# #### Timing Execution

# %%
import time

def timer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"function {func.__name__} took {end_time - start_time:.2f} seconds to execute")
        return result
    return wrapper

@timer
def slow_function():
    time.sleep(3)

slow_function()
# Out:
# function slow_function took 3.00 seconds to execute

# %% [markdown]
# #### Authentication / Authorization

# %%
logged_in = False
def login_required(func):
    def wrapper():
        if not logged_in:
            print("Access denied!")
            return
        return func()
        
    return wrapper
    

@login_required
def dashboard():
    print("Welcome to the dashboard!")

dashboard()
# Out:
# Access denied!

# %% [markdown]
# ### Decorators with Arguments

# %%
def repeat(times):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(times):
                func(*args, **kwargs)
        return wrapper
        
    return decorator

@repeat(3)
def greet():
    print("Hello, welcome to the program!")

greet()
# Out:
# Hello, welcome to the program!
# Hello, welcome to the program!
# Hello, welcome to the program!

# %% [markdown]
# #### Built-in Python Decorators
#
# #### @staticmethod

# %%
class Math:

    @staticmethod
    def add(a, b):
        return a + b

# %% [markdown]
# ### @classmethod

# %%
class Person:
    count = 0
    def __init__(self):
        Person.count += 1
    
    @classmethod
    def total_people(cls):
        return cls.count
